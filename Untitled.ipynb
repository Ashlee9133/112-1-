# %%
from bs4 import *
import pandas as pd
import json
import csv
import re
import time
import importlib
 
# Check if selenium is installed
try:
    print("Checking requirements...")
    importlib.import_module('selenium')
    print('selenium is already installed')
except ImportError:
    print('selenium is not installed, installing now...')
    import subprocess
    subprocess.check_call(['pip', 'install', 'selenium'])
    print('selenium has been installed')
 
 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
 
headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
}
 
 
baseurl = "https://www.winentaste.com/collections/"
wine_type_id = ['36', '39', '40', '41', '42', '43', '769', '278', '884']
 
driver = webdriver.Chrome('./chromedriver') 
 
# clear all
with open('out.csv', 'w', encoding='utf-8') as f:
    f.write('')
 
for i in wine_type_id:
    url = baseurl + i
 
    driver.get(url) 
    print("Connecting to", url, "...")
 
    html = driver.page_source
 
    # find dynamic html data
    pattern = "</a></div><p><a href=\"/products/" + r"\d+" "\">" + r".{0,50}" + "</a></p>"
    result = re.findall(pattern, html)
 
    
    with open('out.csv', 'a', encoding='utf-8') as f:
        fieldnames = ['編號','名稱']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
 
 
        # find title and write in csv
        pattern = "<title>" + r".{0,50}" + "</title>"
        idx = 1
        writer.writerow({'編號' : '-','名稱': '-'})
        writer.writerow({'編號' : 0,'名稱': re.search(pattern, html).group().replace("<title>","").replace("</title>", "").replace("&amp;", "").replace("精選好酒商城｜WINETASTE 品迷網", "")})
        
        for j in result:
            tmp = re.sub(r'[^\u4e00-\u9fff]+', '', j)
            writer.writerow({'編號': idx, '名稱': tmp})
            idx += 1
 
 
 
 
# print csv content
data_HW3csv = pd.read_csv("out.csv",index_col=0)
print(data_HW3csv)
 
 
 
# write in json , csv file and output
with open('out.csv', newline='', encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    rows = list(reader)
with open('out.json', 'w', encoding='utf-8') as jsonfile:
    json.dump(rows, jsonfile, ensure_ascii=False, indent=2)
    
outjson = open('out.json',encoding="utf8")
 
data1_out_json=json.load(outjson)
data1_out_json
# Out:
# Checking requirements...
# selenium is already installed
# <ipython-input-1-9f7bdc0673fd>:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# Connecting to https://www.winentaste.com/collections/36 ...
# Connecting to https://www.winentaste.com/collections/39 ...
# Connecting to https://www.winentaste.com/collections/40 ...
# Connecting to https://www.winentaste.com/collections/41 ...
# Connecting to https://www.winentaste.com/collections/42 ...
# Connecting to https://www.winentaste.com/collections/43 ...
# Connecting to https://www.winentaste.com/collections/769 ...
# Connecting to https://www.winentaste.com/collections/278 ...
# Connecting to https://www.winentaste.com/collections/884 ...
#                          名稱
# 編號
# -                         -
# 0             紅葡萄酒 Red Wine
# 1        透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒
# 2             蝶伊斯柯蘭堡天使絮語粉紅酒
# 3             小林酒造鳳凰美田完熟蜜桃酒
# ..                      ...
# 12            皮爾澤酒莊黑皮諾渣釀白蘭地
# 13  布萊達酒莊烏契洛尼園號渣釀白蘭地附單入精裝紙盒
# 14           多娜佳塔酒莊風之子渣釀白蘭地
# 15         瑞卡梭利男爵酒莊葛拉帕精選白蘭地
# 16         史賓諾拉酒莊豐收白蘭地單入禮盒版
#
# [310 rows x 1 columns]
# [{'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '紅葡萄酒 Red Wine'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '南非莎蒂家族酒莊軌道紅酒'},
#  {'編號': '8', '名稱': '南非莎蒂家族酒莊士兵紅酒'},
#  {'編號': '9', '名稱': '南非莎蒂家族酒莊毒蛇紅酒'},
#  {'編號': '10', '名稱': '南非莎蒂家族酒莊科路美拉紅酒'},
#  {'編號': '11', '名稱': '南非阿爾海特莊園企鵝特攻隊紅酒'},
#  {'編號': '12', '名稱': '蘿拉小酒館小農三號保羅馬爾貝紅酒'},
#  {'編號': '13', '名稱': '雲霧海灣酒莊馬爾堡黑皮諾有機單一園紅酒'},
#  {'編號': '14', '名稱': '拉圖堡一軍紅酒'},
#  {'編號': '15', '名稱': '拉圖堡一軍紅酒'},
#  {'編號': '16', '名稱': '瑪歌堡一軍紅酒'},
#  {'編號': '17', '名稱': '拉圖堡一軍紅酒'},
#  {'編號': '18', '名稱': '拉圖堡一軍紅酒'},
#  {'編號': '19', '名稱': '拉菲堡一軍紅酒'},
#  {'編號': '20', '名稱': '拉菲堡一軍紅酒'},
#  {'編號': '21', '名稱': '歐布里雍堡一軍紅酒'},
#  {'編號': '22', '名稱': '瑪歌堡一軍紅酒'},
#  {'編號': '23', '名稱': '拉圖堡二軍紅酒'},
#  {'編號': '24', '名稱': '悠久酷酒莊面神紅酒'},
#  {'編號': '25', '名稱': '悠久酷酒莊白日夢紅酒'},
#  {'編號': '26', '名稱': '悠久酷酒莊紅酒'},
#  {'編號': '27', '名稱': '悠久酷酒莊松露獵犬紅酒'},
#  {'編號': '28', '名稱': '悠久酷酒莊媽呀的新鮮紅酒'},
#  {'編號': '29', '名稱': '悠久酷酒莊借彼喻此大紅酒'},
#  {'編號': '30', '名稱': '悠久酷酒莊借彼喻此小紅酒'},
#  {'編號': '31', '名稱': '強堤帕西雍酒莊哲維瑞香貝丹村莊級老藤紅酒'},
#  {'編號': '32', '名稱': '強堤帕西雍酒莊上夜丘地區級紅酒'},
#  {'編號': '33', '名稱': '羅伯蒙岱維酒莊烈酒桶陳葡萄酒三入禮盒組'},
#  {'編號': '34', '名稱': '薩佈酒莊黑珍珠紅酒'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '白葡萄酒 White Wine'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '南非莎蒂家族酒莊克絲汀夫人白酒'},
#  {'編號': '8', '名稱': '南非莎蒂家族酒莊足跡白酒'},
#  {'編號': '9', '名稱': '南非莎蒂家族酒莊崎嶇山峰白酒'},
#  {'編號': '10', '名稱': '南非莎蒂家族酒莊毒蠍白酒'},
#  {'編號': '11', '名稱': '南非莎蒂家族酒莊帕拉迪烏斯白酒'},
#  {'編號': '12', '名稱': '南非阿爾海特莊園白夜之火'},
#  {'編號': '13', '名稱': '南非阿爾海特莊園海上黎明'},
#  {'編號': '14', '名稱': '南非阿爾海特莊園赫莫蘭德花園'},
#  {'編號': '15', '名稱': '南非阿爾海特莊園海圖學白酒'},
#  {'編號': '16', '名稱': '南非阿爾海特莊園回顧與展望白酒'},
#  {'編號': '17', '名稱': '雲霧海灣酒莊馬爾堡灰皮諾白葡萄酒'},
#  {'編號': '18', '名稱': '雲霧海灣酒莊馬爾堡白蘇維濃有機單一園白酒'},
#  {'編號': '19', '名稱': '雲霧海灣酒莊馬爾堡白蘇維濃桶陳單一園白酒'},
#  {'編號': '20', '名稱': '雲霧海灣酒莊馬爾堡格烏茲塔明娜匠心單一園白酒'},
#  {'編號': '21', '名稱': '威石東酒莊小威石東白酒'},
#  {'編號': '22', '名稱': '塞格伯蝶酒莊夏布利老藤白酒'},
#  {'編號': '23', '名稱': '悠久酷酒莊沙河費安諾白酒'},
#  {'編號': '24', '名稱': '悠久酷酒莊沖積費安諾白酒'},
#  {'編號': '25', '名稱': '強堤帕西雍酒莊勃根地丘夏多內白酒'},
#  {'編號': '26', '名稱': '巴巴狄優雪莉酒莊大海鰱有機白酒'},
#  {'編號': '27', '名稱': '蝌蚪陶甕白酒'},
#  {'編號': '28', '名稱': '薩佈酒莊黃色蚱蜢白酒'},
#  {'編號': '29', '名稱': '多利士酒莊傳統系列太陽白酒'},
#  {'編號': '30', '名稱': '路易佳鐸酒莊普依富塞村莊級白酒'},
#  {'編號': '31', '名稱': '路易佳鐸酒莊勃根地夏多內白酒'},
#  {'編號': '32', '名稱': '智利多利士酒莊幕斯卡得白酒'},
#  {'編號': '33', '名稱': '希帝酒廠波爾多白酒'},
#  {'編號': '34', '名稱': '太陽之屋酒莊單一園甜型麗絲玲白酒'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '粉紅酒 Rosé Wine'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '雲霧海灣酒莊馬爾堡旗艦粉紅酒'},
#  {'編號': '8', '名稱': '威石東酒莊黑中灰傳統釀造氣泡酒'},
#  {'編號': '9', '名稱': '希帝酒廠波爾多粉紅酒'},
#  {'編號': '10', '名稱': '羅伯希胡歌酒莊巴斯勃根地粉紅酒'},
#  {'編號': '11', '名稱': '多麥黃金黑皮諾粉紅酒'},
#  {'編號': '12', '名稱': '奔馬酒莊國王系列粉鑽粉紅酒'},
#  {'編號': '13', '名稱': '蝶伊斯柯蘭堡搖滾天使粉紅酒'},
#  {'編號': '14', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '15', '名稱': '香檳王粉紅年份香檳禮盒版'},
#  {'編號': '16', '名稱': '香檳王限量版粉紅香檳禮盒'},
#  {'編號': '17', '名稱': '大衛酒莊祖先的酒粉紅酒'},
#  {'編號': '18', '名稱': '格雷西酒莊埃特納火山粉紅酒'},
#  {'編號': '19', '名稱': '庫克香檳陳年粉紅香檳禮盒版'},
#  {'編號': '20', '名稱': '庫克香檳陳年粉紅香檳禮盒版'},
#  {'編號': '21', '名稱': '葛蕾絲酒莊粉紅酒'},
#  {'編號': '22', '名稱': '丸木酒莊貝利粉紅酒'},
#  {'編號': '23', '名稱': '瓦科比古堡芭斯帖粉紅酒'},
#  {'編號': '24', '名稱': '帕里歌李查莊園預言家粉紅勃根地氣泡酒'},
#  {'編號': '25', '名稱': '帕里歌李查莊園單色黑皮諾粉紅氣泡酒'},
#  {'編號': '26', '名稱': '蛇首酒莊咕嘟粉紅酒'},
#  {'編號': '27', '名稱': '香檳王粉紅年份香檳裸瓶'},
#  {'編號': '28', '名稱': '非鳥粉紅無酒精氣泡酒'},
#  {'編號': '29', '名稱': '伯頓莊園美麗甜心粉紅蜜思嘉'},
#  {'編號': '30', '名稱': '法爾內賽酒莊暮夜之后粉紅酒'},
#  {'編號': '31', '名稱': '葛萊美酒莊粉紅不甜香檳'},
#  {'編號': '32', '名稱': '帝富香檳酒莊經典粉紅香檳'},
#  {'編號': '33', '名稱': '森喜酒莊黑皮諾粉紅玫瑰氣泡酒'},
#  {'編號': '34', '名稱': '米拉瓦之花香檳無年份不甜粉紅香檳'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '香檳 Champagne'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '賈克松香檳延遲除渣不甜無年份香檳'},
#  {'編號': '8', '名稱': '賈克松香檳沃澤拉白中黑特級園不甜年份香檳'},
#  {'編號': '9', '名稱': '賈克松香檳該隱園艾維茲白中白特級園不甜年份香檳'},
#  {'編號': '10', '名稱': '賈克松香檳精釀香檳'},
#  {'編號': '11', '名稱': '菲利龐娜香檳皇家陳釀無添糖香檳禮盒版'},
#  {'編號': '12', '名稱': '菲利龐娜香檳皇家陳釀香檳禮盒版'},
#  {'編號': '13', '名稱': '菲利龐娜香檳皇家陳釀粉紅香檳'},
#  {'編號': '14', '名稱': '酩悅香檳週年慶典系列派對雙杯組'},
#  {'編號': '15', '名稱': '慕瑟父子尤金無年份香檳'},
#  {'編號': '16', '名稱': '慕瑟父子年份香檳'},
#  {'編號': '17', '名稱': '皮耶貝桐一級園無年份粉紅香檳'},
#  {'編號': '18', '名稱': '皮耶貝桐白中白年份香檳'},
#  {'編號': '19', '名稱': '皮耶貝桐一級園不甜無年份香檳'},
#  {'編號': '20', '名稱': '馬克艾博哈一級園無年份粉紅香檳'},
#  {'編號': '21', '名稱': '馬克艾博哈一級園不甜精選香檳'},
#  {'編號': '22', '名稱': '督亞香檳白中白特級園年份香檳'},
#  {'編號': '23', '名稱': '督亞香檳修道院一級園白中白年份香檳'},
#  {'編號': '24', '名稱': '皮耶帕亞特級園無年份粉紅香檳'},
#  {'編號': '25', '名稱': '皮耶帕亞特級園豐收不甜年份香檳'},
#  {'編號': '26', '名稱': '皮耶帕亞特級園不甜無年份香檳'},
#  {'編號': '27', '名稱': '埃格麗梧利耶開端不甜無年份香檳'},
#  {'編號': '28', '名稱': '埃格麗梧利耶特級園不甜年份香檳'},
#  {'編號': '29', '名稱': '保羅傑邱吉爾年份香檳禮盒版'},
#  {'編號': '30', '名稱': '凱歌香檳皇牌粉紅香檳週年紀念禮盒'},
#  {'編號': '31', '名稱': '凱歌香檳皇牌香檳週年紀念禮盒'},
#  {'編號': '32', '名稱': '凱歌香檳香檳貴婦草間彌生不甜年份香檳每人限購一瓶'},
#  {'編號': '33', '名稱': '馬克艾博哈一級園白中白無年份香檳'},
#  {'編號': '34', '名稱': '香檳王粉紅年份香檳禮盒版'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '氣泡酒 Sparkling Wine'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '威石東酒莊白中白傳統釀造氣泡酒最後七瓶賣完即斷貨'},
#  {'編號': '8', '名稱': '威石東酒莊黑中灰傳統釀造氣泡酒'},
#  {'編號': '9', '名稱': '威石東酒莊白中白傳統釀造氣泡酒'},
#  {'編號': '10', '名稱': '威石東酒莊小威石東氣泡酒'},
#  {'編號': '11', '名稱': '悠久酷酒莊借彼喻此粉紅古法氣泡酒'},
#  {'編號': '12', '名稱': '悠久酷酒莊借彼喻此氣泡酒'},
#  {'編號': '13', '名稱': '安柏夫人酒莊安柏夫人白中白氣泡酒'},
#  {'編號': '14', '名稱': '狐狸與野兔號自然氣泡橘酒'},
#  {'編號': '15', '名稱': '凱歌香檳皇牌粉紅香檳週年紀念禮盒'},
#  {'編號': '16', '名稱': '凱歌香檳皇牌香檳週年紀念禮盒'},
#  {'編號': '17', '名稱': '羅傑古拉特級陳年氣泡酒'},
#  {'編號': '18', '名稱': '安葛蘿酒莊勃根地氣泡酒'},
#  {'編號': '19', '名稱': '小月亮普羅基克氣泡酒'},
#  {'編號': '20', '名稱': '小月亮粉紅普羅基克氣泡酒'},
#  {'編號': '21', '名稱': '比索酒莊北極星氣泡酒'},
#  {'編號': '22', '名稱': '胡傑父子酒莊經典勃根地氣泡酒'},
#  {'編號': '23', '名稱': '羅培茲酒莊法恩娜微甜氣泡酒'},
#  {'編號': '24', '名稱': '狐狸與野兔奇境自然氣泡橘酒'},
#  {'編號': '25', '名稱': '狐狸與野兔號自然氣泡橘酒'},
#  {'編號': '26', '名稱': '艾瑞克博德雷梨子氣泡酒'},
#  {'編號': '27', '名稱': '艾瑞克博德雷半甘蘋果氣泡酒'},
#  {'編號': '28', '名稱': '吉安尼酒莊旋轉木馬阿斯蒂蜜斯嘉微甜白酒'},
#  {'編號': '29', '名稱': '微物論蠻牛陶甕氣泡酒'},
#  {'編號': '30', '名稱': '馬丁堅石酒莊瘋狂瘋狂橘酒'},
#  {'編號': '31', '名稱': '可樂酒莊北極熊氣泡酒'},
#  {'編號': '32', '名稱': '布魯諾白漾酒莊無年份香檳'},
#  {'編號': '33', '名稱': '布魯諾白漾酒莊旗艦年份香檳'},
#  {'編號': '34', '名稱': '布魯諾白漾酒莊一級園無年份粉紅香檳'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '甜酒 Sweet Wine'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '慕瑟父子香檳加烈甜酒'},
#  {'編號': '8', '名稱': '羅伯威爾酒莊傳統風格麗絲玲甜白酒'},
#  {'編號': '9', '名稱': '羅伯威爾酒莊麗絲玲卡必內級微甜白酒'},
#  {'編號': '10', '名稱': '羅伯威爾酒莊麗絲玲遲摘級甜白酒'},
#  {'編號': '11', '名稱': '羅伯威爾酒莊伯爵山遲摘級微甜白酒'},
#  {'編號': '12', '名稱': '羅伯威爾酒莊伯爵山特選級甜白酒'},
#  {'編號': '13', '名稱': '拜拉酒莊蜜思嘉微甜白酒'},
#  {'編號': '14', '名稱': '迪伯多莉酒莊傳奇藝術聯名系列榭蜜雍貴腐甜酒'},
#  {'編號': '15', '名稱': '吉里莊園瑪爾維薩微甜微氣泡紅酒'},
#  {'編號': '16', '名稱': '胡賽克堡貴腐甜白酒'},
#  {'編號': '17', '名稱': '胡賽克堡貴腐甜白酒'},
#  {'編號': '18', '名稱': '克里蒙斯堡一軍貴腐甜白酒'},
#  {'編號': '19', '名稱': '羅培茲酒莊法恩娜微甜氣泡酒'},
#  {'編號': '20', '名稱': '佳樂酒莊玫瑰香細緻甜白葡萄酒'},
#  {'編號': '21', '名稱': '卡爾格拉夫酒莊麗絲玲珍藏白葡萄酒'},
#  {'編號': '22', '名稱': '吉安尼酒莊旋轉木馬阿斯蒂蜜斯嘉微甜白酒'},
#  {'編號': '23', '名稱': '達文西酒莊莊園聖酒甜白酒'},
#  {'編號': '24', '名稱': '葛蘭博城堡甜白酒'},
#  {'編號': '25', '名稱': '崗夏酒莊阿斯提無年份微甜氣泡酒'},
#  {'編號': '26', '名稱': '亞當酒莊花園麗絲玲微甜白酒'},
#  {'編號': '27', '名稱': '伊更堡貴腐甜白酒'},
#  {'編號': '28', '名稱': '弗利茲哈格酒莊棕山日晷特級園晚摘甜白酒'},
#  {'編號': '29', '名稱': '幸運星蜜斯嘉微甜氣泡酒'},
#  {'編號': '30', '名稱': '伊更堡貴腐甜白酒'},
#  {'編號': '31', '名稱': '莎拉蔻酒莊蜜斯嘉微氣泡甜酒櫻花限量標'},
#  {'編號': '32', '名稱': '布斯卡斯古堡月甜白酒'},
#  {'編號': '33', '名稱': '露飛諾酒莊蜜思嘉微氣泡甜白酒'},
#  {'編號': '34', '名稱': '伯頓莊園美麗甜心粉紅蜜思嘉'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '貴腐酒'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '迪伯多莉酒莊傳奇藝術聯名系列榭蜜雍貴腐甜酒'},
#  {'編號': '8', '名稱': '胡賽克堡貴腐甜白酒'},
#  {'編號': '9', '名稱': '胡賽克堡貴腐甜白酒'},
#  {'編號': '10', '名稱': '克里蒙斯堡一軍貴腐甜白酒'},
#  {'編號': '11', '名稱': '伊更堡貴腐甜白酒'},
#  {'編號': '12', '名稱': '伊更堡貴腐甜白酒'},
#  {'編號': '13', '名稱': '伯頓莊園頂級釀酒師鑽石典藏貴腐甜白葡萄酒'},
#  {'編號': '14', '名稱': '迪恩號桶榭密雍貴腐甜白酒'},
#  {'編號': '15', '名稱': '迪伯多利酒莊第一貴族貴腐甜白葡萄酒'},
#  {'編號': '16', '名稱': '安蒂諾里酒莊慕法朵貴腐甜白酒'},
#  {'編號': '17', '名稱': '西隆酒莊格英克洛貴腐甜白酒'},
#  {'編號': '18', '名稱': '豚岩酒莊托凱貴腐甜酒'},
#  {'編號': '19', '名稱': '亞當酒莊賀福園逐粒精選貴腐酒'},
#  {'編號': '20', '名稱': '杜道酒廠索坦甜白酒'},
#  {'編號': '21', '名稱': '豚岩酒莊晚摘甜白酒'},
#  {'編號': '22', '名稱': '西隆酒莊格英克洛貴腐甜白酒'},
#  {'編號': '23', '名稱': '庫特堡貴腐甜白酒'},
#  {'編號': '24', '名稱': '伊更堡貴腐甜白酒'},
#  {'編號': '25', '名稱': '旭金堡一軍索甸貴腐甜白酒'},
#  {'編號': '26', '名稱': '伊更堡貴腐甜白酒'},
#  {'編號': '27', '名稱': '蒙多業古堡蒙巴季亞克貴腐甜酒'},
#  {'編號': '28', '名稱': '波內米斯男爵酒莊托凱貴腐甜白酒'},
#  {'編號': '29', '名稱': '迪伯多利酒廠第一貴族貴腐甜白酒'},
#  {'編號': '30', '名稱': '雅倫布酒莊維歐尼耶貴腐甜白酒完售補貨中'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '橘酒 Orange Wine'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '悠久酷酒莊秘密宗教混釀橘酒'},
#  {'編號': '8', '名稱': '狐狸與野兔號自然氣泡橘酒'},
#  {'編號': '9', '名稱': '渴望酒莊熱帶鳥輕橘酒'},
#  {'編號': '10', '名稱': '山形酒莊葡萄共和國橘酒'},
#  {'編號': '11', '名稱': '蛇首酒莊咕嘟橘酒'},
#  {'編號': '12', '名稱': '雷迪肯酒莊雅可橘酒'},
#  {'編號': '13', '名稱': '神獸酒莊陶甕橘酒'},
#  {'編號': '14', '名稱': '神獸酒莊陶甕橘酒'},
#  {'編號': '15', '名稱': '朵蕊咪酒莊牽手的我們陶甕橘酒'},
#  {'編號': '16', '名稱': '朵蕊咪酒莊青春的你陶甕橘酒'},
#  {'編號': '17', '名稱': '狐狸與野兔奇境自然氣泡橘酒'},
#  {'編號': '18', '名稱': '狐狸與野兔號自然氣泡橘酒'},
#  {'編號': '19', '名稱': '雷迪肯酒莊橘酒'},
#  {'編號': '20', '名稱': '微物論伊始陶甕橘酒'},
#  {'編號': '21', '名稱': '馬丁堅石酒莊瘋狂瘋狂橘酒'},
#  {'編號': '22', '名稱': '左右不分酒莊五彩斑斕的日出橘酒'},
#  {'編號': '23', '名稱': '九能酒莊非洲菊'},
#  {'編號': '24', '名稱': '悠曲曲酒莊瘋狂的愛綠翡特利納橘酒'},
#  {'編號': '25', '名稱': '悠曲曲酒莊蒙布朗橘酒'},
#  {'編號': '26', '名稱': '悠曲曲酒莊美人天成綠翡特利納橘酒'},
#  {'編號': '27', '名稱': '狐狸與野兔號自然氣泡橘酒'},
#  {'編號': '28', '名稱': '芳塔娜酒莊歐維佳黑羊橘酒'},
#  {'編號': '29', '名稱': '雷迪肯酒莊奧斯拉維耶橘酒'},
#  {'編號': '30', '名稱': '雷迪肯酒莊雷布拉橘酒'},
#  {'編號': '31', '名稱': '海維克酒莊自由蜜斯嘉橘酒'},
#  {'編號': '32', '名稱': '野雞的眼淚酒莊卡胡里慕滋威瓦尼橘酒'},
#  {'編號': '33', '名稱': '威石東酒莊陶罐木杉橘酒'},
#  {'編號': '34', '名稱': '威石東酒莊陶罐木杉古法氣泡橘酒'},
#  {'編號': '編號', '名稱': '名稱'},
#  {'編號': '-', '名稱': '-'},
#  {'編號': '0', '名稱': '白蘭地 Brandy'},
#  {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'},
#  {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'},
#  {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'},
#  {'編號': '7', '名稱': '艾吉歐拉斯酒莊特列蒙提斯渣釀白蘭地'},
#  {'編號': '8', '名稱': '艾吉安諾酒莊布魯內羅渣釀白蘭地附單入精裝紙盒'},
#  {'編號': '9', '名稱': '嘉洛菲利酒莊頒獎台渣釀白蘭地'},
#  {'編號': '10', '名稱': '湯瑪士家族酒莊古典阿瑪諾內渣釀白蘭地'},
#  {'編號': '11', '名稱': '特德斯基酒莊歐米山園阿瑪諾內渣釀白蘭地附單入精裝紙盒'},
#  {'編號': '12', '名稱': '皮爾澤酒莊黑皮諾渣釀白蘭地'},
#  {'編號': '13', '名稱': '布萊達酒莊烏契洛尼園號渣釀白蘭地附單入精裝紙盒'},
#  {'編號': '14', '名稱': '多娜佳塔酒莊風之子渣釀白蘭地'},
#  {'編號': '15', '名稱': '瑞卡梭利男爵酒莊葛拉帕精選白蘭地'},
#  {'編號': '16', '名稱': '史賓諾拉酒莊豐收白蘭地單入禮盒版'}]

# %%
for i in data1_out_json:
    print(i['名稱'])
# Out:
# -
# 紅葡萄酒 Red Wine
# 透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒
# 蝶伊斯柯蘭堡天使絮語粉紅酒
# 小林酒造鳳凰美田完熟蜜桃酒
# 透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒
# 蝶伊斯柯蘭堡天使絮語粉紅酒
# 小林酒造鳳凰美田完熟蜜桃酒
#