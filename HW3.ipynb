# %%
from bs4 import *
import pandas as pd
import json
import csv
import re
import time
import importlib
 
# Check if selenium is installed
try:
    print("Checking requirements...")
    importlib.import_module('selenium')
    print('selenium is already installed')
except ImportError:
    print('selenium is not installed, installing now...')
    import subprocess
    subprocess.check_call(['pip', 'install', 'selenium'])
    print('selenium has been installed')
 
 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
 
headers={
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36"
}
 
 
baseurl = "https://www.winentaste.com/collections/"
wine_type_id = ['36', '39', '40', '41', '42', '43', '769', '278', '884']
 
driver = webdriver.Chrome('./chromedriver') 
 
# clear all
with open('out.csv', 'w', encoding='utf-8') as f:
    f.write('')
 
for i in wine_type_id:
    url = baseurl + i
 
    driver.get(url) 
    print("Connecting to", url, "...")
 
    html = driver.page_source
 
    # find dynamic html data
    pattern = "</a></div><p><a href=\"/products/" + r"\d+" "\">" + r".{0,50}" + "</a></p>"
    result = re.findall(pattern, html)
 
    
    with open('out.csv', 'a', encoding='utf-8') as f:
        fieldnames = ['編號','名稱']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
 
 
        # find title and write in csv
        pattern = "<title>" + r".{0,50}" + "</title>"
        idx = 1
        writer.writerow({'編號' : '-','名稱': '-'})
        writer.writerow({'編號' : 0,'名稱': re.search(pattern, html).group().replace("<title>","").replace("</title>", "").replace("&amp;", "").replace("精選好酒商城｜WINETASTE 品迷網", "")})
        
        for j in result:
            tmp = re.sub(r'[^\u4e00-\u9fff]+', '', j)
            writer.writerow({'編號': idx, '名稱': tmp})
            idx += 1
 
 
 
 
# print csv content
data_HW3csv = pd.read_csv("out.csv",index_col=0)
print(data_HW3csv)
 
 
 
# write in json , csv file and output
with open('out.csv', newline='', encoding='utf-8-sig') as csvfile:
    reader = csv.DictReader(csvfile)
    rows = list(reader)
with open('out.json', 'w', encoding='utf-8') as jsonfile:
    json.dump(rows, jsonfile, ensure_ascii=False, indent=2)
    
outjson = open('out.json',encoding="utf8")
 
data1_out_json=json.load(outjson)
print(data1_out_json)
# Out:
# Checking requirements...
# selenium is already installed
# <ipython-input-4-b0c3dd613943>:32: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver')
# Connecting to https://www.winentaste.com/collections/36 ...
# Connecting to https://www.winentaste.com/collections/39 ...
# Connecting to https://www.winentaste.com/collections/40 ...
# Connecting to https://www.winentaste.com/collections/41 ...
# Connecting to https://www.winentaste.com/collections/42 ...
# Connecting to https://www.winentaste.com/collections/43 ...
# Connecting to https://www.winentaste.com/collections/769 ...
# Connecting to https://www.winentaste.com/collections/278 ...
# Connecting to https://www.winentaste.com/collections/884 ...
#                          名稱
# 編號
# -                         -
# 0             紅葡萄酒 Red Wine
# 1        透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒
# 2             蝶伊斯柯蘭堡天使絮語粉紅酒
# 3             小林酒造鳳凰美田完熟蜜桃酒
# ..                      ...
# 12            皮爾澤酒莊黑皮諾渣釀白蘭地
# 13  布萊達酒莊烏契洛尼園號渣釀白蘭地附單入精裝紙盒
# 14           多娜佳塔酒莊風之子渣釀白蘭地
# 15         瑞卡梭利男爵酒莊葛拉帕精選白蘭地
# 16         史賓諾拉酒莊豐收白蘭地單入禮盒版
#
# [310 rows x 1 columns]
# [{'編號': '-', '名稱': '-'}, {'編號': '0', '名稱': '紅葡萄酒 Red Wine'}, {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'}, {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'}, {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'}, {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'}, {'編號': '7', '名稱': '羅伯希胡歌酒莊大艾雪索特級園紅酒'}, {'編號': '8', '名稱': '太陽之屋酒莊單一園克萊文黑皮諾紅酒'}, {'編號': '9', '名稱': '羅伯希胡歌酒莊大艾雪索特級園紅酒'}, {'編號': '10', '名稱': '羅伯希胡歌酒莊馮內侯曼內一級園小山坡紅酒'}, {'編號': '11', '名稱': '羅伯希胡歌酒莊馮內侯曼內老藤紅酒'}, {'編號': '12', '名稱': '羅伯希胡歌酒莊香波蜜斯妮蒙彼紅酒'}, {'編號': '13', '名稱': '羅伯希胡歌酒莊拉朵瓦村莊紅酒'}, {'編號': '14', '名稱': '阿諾莫泰酒莊夏姆香貝丹特級園紅酒'}, {'編號': '15', '名稱': '阿諾莫泰酒莊瑪澤耶香貝丹特級園紅酒'}, {'編號': '16', '名稱': '阿諾莫泰酒莊哲維瑞香貝丹一級園紅酒'}, {'編號': '17', '名稱': '阿諾莫泰酒莊哲維瑞香貝丹一級園紅酒'}, {'編號': '18', '名稱': '阿諾莫泰酒莊哲維瑞香貝丹老藤紅酒'}, {'編號': '19', '名稱': '阿諾莫泰酒莊哲維瑞香貝丹紅酒'}, {'編號': '20', '名稱': '羅伯希胡歌酒莊勃根地黑皮諾紅酒'}, {'編號': '21', '名稱': '羅伯希胡歌酒莊馮內侯曼內紅酒'}, {'編號': '22', '名稱': '羅伯希胡歌酒莊巴斯勃根地紅酒'}, {'編號': '23', '名稱': '法國康美濃堡波爾多頂級精釀紅葡萄酒'}, {'編號': '24', '名稱': '卡帕爾佐酒莊桑嬌維賽紅酒'}, {'編號': '25', '名稱': '智利多利士酒莊公平交易系列村莊精選紅酒'}, {'編號': '26', '名稱': '胡黛爾堡紅酒'}, {'編號': '27', '名稱': '單身女郎巴貝拉紅酒'}, {'編號': '28', '名稱': '積架酒莊聖喬瑟夫紅酒'}, {'編號': '29', '名稱': '積架酒莊吉恭達斯紅酒'}, {'編號': '30', '名稱': '積架酒莊教皇新堡紅酒'}, {'編號': '31', '名稱': '辛卡儂酒莊希哈精釀紅酒'}, {'編號': '32', '名稱': '辛卡儂酒莊格納希精釀紅酒'}, {'編號': '33', '名稱': '蔻兒耿酒莊泰頌丘陵園卡本內蘇維儂精釀紅酒預計四月中旬出貨'}, {'編號': '34', '名稱': '蔻兒耿酒莊第九莊園精釀紅酒預計四月中旬出貨'}, {'編號': '編號', '名稱': '名稱'}, {'編號': '-', '名稱': '-'}, {'編號': '0', '名稱': '白葡萄酒 White Wine'}, {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'}, {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'}, {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'}, {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'}, {'編號': '7', '名稱': '太陽之屋酒莊單一園甜型麗絲玲白酒'}, {'編號': '8', '名稱': '太陽之屋酒莊單一園不甜麗絲玲白酒'}, {'編號': '9', '名稱': '太陽之屋酒莊媮魯單一園混釀白酒'}, {'編號': '10', '名稱': '太陽之屋酒莊白蘇維濃白酒'}, {'編號': '11', '名稱': '羅伯希胡歌酒莊阿里歌蝶白酒'}, {'編號': '12', '名稱': '智利多利士酒莊幕斯卡得白酒'}, {'編號': '13', '名稱': '積架酒莊恭德里奧多利安娜單一園白酒'}, {'編號': '14', '名稱': '積架酒莊聖喬瑟夫白酒'}, {'編號': '15', '名稱': '積架酒莊恭德里奧白酒'}, {'編號': '16', '名稱': '辛卡儂酒莊精釀白酒'}, {'編號': '17', '名稱': '羅伯威爾酒莊麗絲玲不甜白酒'}, {'編號': '18', '名稱': '羅伯威爾酒莊傳統風格麗絲玲甜白酒'}, {'編號': '19', '名稱': '羅伯威爾酒莊麗絲玲卡必內級微甜白酒'}, {'編號': '20', '名稱': '羅伯威爾酒莊麗絲玲遲摘級甜白酒'}, {'編號': '21', '名稱': '羅伯威爾酒莊塔山一級園不甜白酒'}, {'編號': '22', '名稱': '羅伯威爾酒莊伯爵山遲摘級微甜白酒'}, {'編號': '23', '名稱': '羅伯威爾酒莊伯爵山頂級園不甜白酒'}, {'編號': '24', '名稱': '羅伯威爾酒莊伯爵山特選級甜白酒'}, {'編號': '25', '名稱': '雲霧之灣酒莊蒂蔻蔻白酒'}, {'編號': '26', '名稱': '葛羅兄妹酒莊金盃上夜丘地區級白酒'}, {'編號': '27', '名稱': '夏娃酒莊貓頭鷹系列雪鴞白酒'}, {'編號': '28', '名稱': '葵莎酒莊精選白蘇維濃白酒'}, {'編號': '29', '名稱': '貝赫特邦德酒莊侏羅丘窖藏傳統白酒'}, {'編號': '30', '名稱': '夏布利酒莊夏布利青蛙園特級園白酒'}, {'編號': '31', '名稱': '夏布利酒莊普爾日特級園白酒'}, {'編號': '32', '名稱': '夏布利酒莊布果特級園白酒'}, {'編號': '33', '名稱': '夏布利酒莊夏布利彼悅白酒'}, {'編號': '34', '名稱': '樂弗雷酒莊普里尼蒙哈榭弗拉堤耶一級園白酒'}, {'編號': '編號', '名稱': '名稱'}, {'編號': '-', '名稱': '-'}, {'編號': '0', '名稱': '粉紅酒 Rosé Wine'}, {'編號': '1', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'}, {'編號': '2', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '3', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'}, {'編號': '4', '名稱': '透湖酒莊馬爾堡阿瓦蒂爾谷白蘇維濃白酒'}, {'編號': '5', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '6', '名稱': '小林酒造鳳凰美田完熟蜜桃酒'}, {'編號': '7', '名稱': '羅伯希胡歌酒莊巴斯勃根地粉紅酒'}, {'編號': '8', '名稱': '多麥黃金黑皮諾粉紅酒'}, {'編號': '9', '名稱': '奔馬酒莊國王系列粉鑽粉紅酒'}, {'編號': '10', '名稱': '蝶伊斯柯蘭堡搖滾天使粉紅酒'}, {'編號': '11', '名稱': '蝶伊斯柯蘭堡天使絮語粉紅酒'}, {'編號': '12', '名稱': '威石東酒莊黑中灰傳統釀造氣泡酒'}, {'編號': '13', '名稱': '香檳王粉紅年份香檳禮盒版'}, {'編號': '14', '名稱': '香檳王限量版粉紅香檳禮盒'}, {'編號': '15', '名稱': '大衛酒莊祖先的酒粉紅酒'}, {'編號': '16', '名稱': '格雷西酒莊埃特納火山粉紅酒'}, {'編號': '17', '名稱': '庫克香檳陳年粉紅香檳禮盒版'}, {'編號': '18', '名稱': '庫克香檳陳年粉紅香檳禮盒版'}, {'編號': '19', '名稱': '雲霧海灣酒莊馬爾堡旗艦粉紅酒'}, {'編號': '20', '名稱': '葛蕾絲酒莊粉紅酒'}, {'編號': '21', '名稱': '丸木酒莊貝利粉紅酒'}, {'編號': '22', '名稱': '瓦科比古堡芭斯帖粉紅酒'}, {'編號': '23', '名稱': '帕里歌李查莊園預言家粉紅勃根地氣泡酒'}, {'編號': '24', '名稱': '帕里歌李查莊園單色黑皮諾粉紅氣泡酒'}, {'編號': '25', '名稱': '蛇首酒莊咕嘟粉紅酒'}, {'編號': '26', '名稱': '香檳王粉紅年份香檳裸瓶'}, {'編號': '27', '名稱': '非鳥粉紅無酒精氣泡酒'}, {'編號': '28', '名稱': '伯頓莊園美麗甜心粉紅蜜思嘉'}, {'編號': '29', '名稱': '法爾內賽酒莊暮夜之后粉紅酒'}, {'編號': '30', '名稱': '葛萊美酒莊粉紅不甜香檳'}, {'編號': '31', '名稱': '帝富香檳酒莊經典粉紅香檳'}, {'編號': '32', '名稱': '森喜酒莊黑皮諾粉 ...
